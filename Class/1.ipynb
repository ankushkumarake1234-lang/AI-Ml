# %%
import pandas as pd

# %%
t = pd.read_csv('planets.csv')

# %%
df = pd.read_csv('Titanic-Dataset.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
result = df[df['Age'] > 65][['Pclass','Name','Fare']]
print(result)
# Out:
#      Pclass                                  Name     Fare
# 33        2                 Wheadon, Mr. Edward H  10.5000
# 96        1             Goldschmidt, Mr. George B  34.6542
# 116       3                  Connors, Mr. Patrick   7.7500
# 493       1               Artagaveytia, Mr. Ramon  49.5042
# 630       1  Barkworth, Mr. Algernon Henry Wilson  30.0000
# 672       2           Mitchell, Mr. Henry Michael  10.5000
# 745       1          Crosby, Capt. Edward Gifford  71.0000
# 851       3                   Svensson, Mr. Johan   7.7750

# %%
df[~(df['Embarked'] == 'S')].shape[0]
# Out:
# 247

# %%
df[(df['Age'] < 10) | (df['Age'] > 70)].shape[0]
# Out:
# 67

# %%
df['Pclass'].value_counts()
df[df['Pclass'] == 3]['Sex'].value_counts()
# Out:
# Sex
# male      347
# female    144
# Name: count, dtype: int64

# %%
df['Parch'].value_counts()
df[df['Parch'] == 0]['Sex'].value_counts()
df['Travel-group'] = "alone"
df.loc[(df['SibSp'] + df['Parch']) > 0, 'travel_group'] = 'with family'
df['Travel-group'].value_counts()
# Out:
# Travel-group
# alone    891
# Name: count, dtype: int64

# %%
p = pd.read_csv('/Users/ankushkumar/AI-Ml/Class/planets (1).csv')
p.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
# find the missing value
p.isnull().sum()
# Out:
# Planet                           0
# Color                            0
# Mass (10^24kg)                   0
# Diameter (km)                    0
# Density (kg/m^3)                 0
# Surface Gravity(m/s^2)           0
# Escape Velocity (km/s)           0
# Rotation Period (hours)          0
# Length of Day (hours)            0
# Distance from Sun (10^6 km)      0
# Perihelion (10^6 km)             0
# Aphelion (10^6 km)               0
# Orbital Period (days)            0
# Orbital Velocity (km/s)          0
# Orbital Inclination (degrees)    0
# Orbital Eccentricity             0
# Obliquity to Orbit (degrees)     0
# Mean Temperature (C)             0
# Surface Pressure (bars)          0
# Number of Moons                  0
# Ring System?                     0
# Global Magnetic Field?           0
# dtype: int64

# %%
print(p['mass'].isnull().sum())
# Out:
# 522

# %%
p.dropna(inplace=True)
p.dropna().sum()
# Out:
# Planet                             MercuryVenusEarthMarsJupiterSaturnUranusNeptune
# Color                            GreyBrown and GreyBlue, Brown Green and WhiteR...
# Mass (10^24kg)                                                            2666.612
# Diameter (km)                                                               400697
# Density (kg/m^3)                                                             25041
# Surface Gravity(m/s^2)                                                        77.9
# Escape Velocity (km/s)                                                       170.7
# Rotation Period (hours)                                                    -4356.9
# Length of Day (hours)                                                       7127.2
# Distance from Sun (10^6 km)                                                10136.2
# Perihelion (10^6 km)                                                        9809.3
# ...

# %%
p.dropna(subset=['mass'])
# Out:
#               method  number  orbital_period    mass  distance  year
# 0    Radial Velocity       1         269.300   7.100     77.40  2006
# 1    Radial Velocity       1         874.774   2.210     56.95  2008
# 2    Radial Velocity       1         763.000   2.600     19.84  2011
# 3    Radial Velocity       1         326.030  19.400    110.62  2007
# 4    Radial Velocity       1         516.220  10.500    119.47  2009
# ..               ...     ...             ...     ...       ...   ...
# 784  Radial Velocity       3         580.000   0.947    135.00  2012
# 913  Radial Velocity       1         677.800  19.800       NaN  2007
# 914  Radial Velocity       1           6.958   0.340       NaN  2014
# 915  Radial Velocity       1           5.118   0.400       NaN  2014
# 916  Radial Velocity       1         121.710   1.540       NaN  2014
#
# [513 rows x 6 columns]

# %%
p.dropna(axis=1)
# Out:
#                method  number  year
# 0     Radial Velocity       1  2006
# 1     Radial Velocity       1  2008
# 2     Radial Velocity       1  2011
# 3     Radial Velocity       1  2007
# 4     Radial Velocity       1  2009
# ...               ...     ...   ...
# 1030          Transit       1  2006
# 1031          Transit       1  2007
# 1032          Transit       1  2007
# 1033          Transit       1  2008
# 1034          Transit       1  2008
#
# [1035 rows x 3 columns]

# %%
p['mass'].fillna(0)
p['mass'].fillna(p['mass'].mean())
p['mass'].fillna(p['mass'].median())
p['mass'].fillna(0).isnull().sum()
# Out:
# np.int64(0)

# %%
p.duplicated().sum()
df.duplicated().sum()
t.duplicated().sum()
# Out:
# np.int64(0)

# %%
p.drop_duplicates()
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1031 rows x 6 columns]

# %%
ans = p.drop_duplicates(subset=['method'],ignore_index=True)
print(ans)
# Out:
#                           method  number  orbital_period  mass  distance  year
# 0                Radial Velocity       1      269.300000  7.10     77.40  2006
# 1                        Imaging       1             NaN   NaN     45.52  2005
# 2      Eclipse Timing Variations       1    10220.000000  6.05       NaN  2009
# 3                        Transit       1        1.508956   NaN       NaN  2008
# 4                     Astrometry       1      246.360000   NaN     20.77  2013
# 5      Transit Timing Variations       2      160.000000   NaN   2119.00  2011
# 6  Orbital Brightness Modulation       2        0.240104   NaN   1180.00  2011
# 7                   Microlensing       1             NaN   NaN       NaN  2008
# 8                  Pulsar Timing       3       25.262000   NaN       NaN  1992
# 9    Pulsation Timing Variations       1     1170.000000   NaN       NaN  2007

# %%
# quetsion 1
#

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('Titanic-Dataset.csv')
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic = pd.read_csv('/Users/ankushkumar/AI-Ml/Class/Titanic-Dataset.csv')
tip = pd.read_csv('/Users/ankushkumar/AI-Ml/Class/tips.csv')

# %%
tip.groupby('day').size()
tip.groupby('day')['tip'].mean().round(2)
tip.groupby('day')['tip'].median().round(2)
# Out:
# day
# Fri     3.00
# Sat     2.75
# Sun     3.15
# Thur    2.30
# Name: tip, dtype: float64

# %%
tip_act = tip.groupby('day')['tip'].mean()
tip_sum = tip.groupby('day')['tip'].sum()
print(tip_act)
# Out:
# day
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Thur    2.771452
# Name: tip, dtype: float64

# %%
tip['tip_pct'] = round(tip['tip'] / tip['total_bill']*100,2)
tip.head(2)
tip.groupby('day')['tip_pct'].mean().round(2)
# Out:
# day
# Fri     16.99
# Sat     15.31
# Sun     16.69
# Thur    16.13
# Name: tip_pct, dtype: float64

# %%
tip.groupby('day')['tip'].mean()
tip.groupby('day').mean(numeric_only=True)
tip.groupby('day')

# %%
tip.groupby('day').mean(numeric_only=True)["tip"]
tip.groupby('day')['tip'].mean()
# Out:
# day
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Thur    2.771452
# Name: tip, dtype: float64

# %%
tip.groupby('size')['tip_pct'].mean().round(2)
# Out:
# size
# 1    21.73
# 2    16.57
# 3    15.21
# 4    14.59
# 5    14.15
# 6    15.62
# Name: tip_pct, dtype: float64

# %%
tip.groupby('size')['total_bill'].mean().round(2)
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tip_pct
# 0  Christy Cunningham  3560325168603410    Sun2959     5.94
# 1      Douglas Tucker  4478071379779230    Sun4608    16.05
# 2      Travis Walters  6011812112971322    Sun4458    16.66
# 3    Nathaniel Harris  4676137647685994    Sun5260    13.98
# 4        Tonya Carter  4832732618637221    Sun2251    14.68

# %%
tip.groupby('day')['smoker'].value_counts()
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.groupby('Pclass')['Survived'].mean().round(2)*100
# Out:
# Pclass
# 1    63.0
# 2    47.0
# 3    24.0
# Name: Survived, dtype: float64

# %%
titanic.groupby('Pclass')['Fare'].mean().round(2)
# Out:
# Pclass
# 1    84.15
# 2    20.66
# 3    13.68
# Name: Fare, dtype: float64

# %%
titanic.groupby('Embarked')['Age'].mean().round(2)
# Out:
# Embarked
# C    30.81
# Q    28.09
# S    29.45
# Name: Age, dtype: float64
