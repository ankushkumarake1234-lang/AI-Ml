# %%
import pandas as pd
import numpy as np

# %%
x = np.random.randn(5)
print(x)
y = np.random.randint(1, 101, 5)
print(y)
# Out:
# [-1.34343283  1.20021436  0.82018599  1.22333278 -0.05728342]
# [73 87 47 13 50]
