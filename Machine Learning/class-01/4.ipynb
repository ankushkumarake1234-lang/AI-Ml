# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/Users/ankushkumar/AI-Ml/Machine Learning/class-01/placement.csv')
df.head()
# Out:
#   student_id  cgpa  twelfth_percent branch  internships  projects  backlogs  \
# 0     VS2821  7.41             78.5     IT          0.0         6         1
# 1     VS3068  7.52             70.0    CSE          2.0         3         0
# 2     VS2940  7.35             78.3    CSE          2.0         0         3
# 3     VS3138  7.86             60.2    CSE          1.0         3         0
# 4     VS2670  5.63             88.3    CSE          2.0         2         0
#
#    prep_hours  communication_score hostel placed  package_lpa
# 0       188.0                  4.3     No     No         0.00
# 1       167.0                  9.8    Yes    Yes        10.06
# 2       199.0                  4.8    Yes    Yes          NaN
# 3       135.0                  8.0     No    Yes         8.63
# 4       132.0                  6.3     No    Yes         5.22

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   student_id           550 non-null    str
#  1   cgpa                 550 non-null    float64
#  2   twelfth_percent      550 non-null    float64
#  3   branch               550 non-null    str
#  4   internships          519 non-null    float64
#  5   projects             550 non-null    int64
#  6   backlogs             550 non-null    int64
#  7   prep_hours           454 non-null    float64
#  8   communication_score  538 non-null    float64
#  9   hostel               550 non-null    str
#  10  placed               550 non-null    str
#  11  package_lpa          517 non-null    float64
# dtypes: float64(6), int64(2), str(4)
# memory usage: 59.4 KB

# %%
#  Step 1 - Load and look
df.describe().columns
# Out:
# Index(['cgpa', 'twelfth_percent', 'internships', 'projects', 'backlogs',
#        'prep_hours', 'communication_score', 'package_lpa'],
#       dtype='str')

# %%
# Separate numeric and categorical columns
nums = (['cgpa', 'twelfth_percent', 'internships', 'projects', 'backlogs',
       'prep_hours', 'communication_score', 'package_lpa'])
cat_col = ['branch', 'hostel']

# %%
# Step 3 - Split into X and y
df.info()
X = df.drop(columns=['student_id', 'package_lpa', 'placed'])
y = df['placed']

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   student_id           550 non-null    str
#  1   cgpa                 550 non-null    float64
#  2   twelfth_percent      550 non-null    float64
#  3   branch               550 non-null    str
#  4   internships          519 non-null    float64
#  5   projects             550 non-null    int64
#  6   backlogs             550 non-null    int64
#  7   prep_hours           454 non-null    float64
#  8   communication_score  538 non-null    float64
#  9   hostel               550 non-null    str
#  10  placed               550 non-null    str
#  11  package_lpa          517 non-null    float64
# dtypes: float64(6), int64(2), str(4)
# memory usage: 59.4 KB
# X shape: (550, 9)
# y shape: (550,)

# %%
nums = X.select_dtypes(include='number').columns

# Fill missing numerical values with mean
for col in nums:
    X[col] = X[col].fillna(X[col].mean())

# %%
df.isnull().sum()
# Out:
# student_id              0
# cgpa                    0
# twelfth_percent         0
# branch                  0
# internships            31
# projects                0
# backlogs                0
# prep_hours             96
# communication_score    12
# hostel                  0
# placed                  0
# package_lpa            33
# dtype: int64

# %%
# Step 4 - Handle missing values
df.isnull().sum()
# Out:
# student_id              0
# cgpa                    0
# twelfth_percent         0
# branch                  0
# internships            31
# projects                0
# backlogs                0
# prep_hours             96
# communication_score    12
# hostel                  0
# placed                  0
# package_lpa            33
# dtype: int64

# %%
# Step 5 - Encode categorical columns
print(cat_col)
# Out:
# ['branch', 'hostel']

# %%
df['branch'].value_counts()
# Out:
# branch
# CSE      167
# IT       118
# ECE      112
# Mech     103
# Civil     50
# Name: count, dtype: int64

# %%
df['hostel'].value_counts()
# Out:
# hostel
# Yes    317
# No     233
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
encoder = OneHotEncoder(sparse_output=False)

# %%
encoded = encoder.fit_transform(X[cat_col])
print((encoded.shape))
# Out:
# (550, 7)

# %%
print(type(encoded))
# Out:
# <class 'numpy.ndarray'>

# %%
# Step 6 - Scale numeric columns

from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaled = scaler.fit_transform(X[nums])
print(scaled.shape)
# Out:
# (550, 7)

# %%
# print(scaled.describe())

# %%
# Step 7 - Both together with ColumnTransformer
from sklearn.compose import ColumnTransformer

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), nums),
        ('cat', OneHotEncoder(sparse_output=False), cat_col)
    # ],
    # remainder='passthrough')  
    ]
)

# %%
final_transformed = preprocessor.fit_transform(X)

# %%
final_transformed.shape
# Out:
# (550, 14)

# %%
preprocessor.get_feature_names_out()
# Out:
# array(['num__cgpa', 'num__twelfth_percent', 'num__internships',
#        'num__projects', 'num__backlogs', 'num__prep_hours',
#        'num__communication_score', 'cat__branch_CSE', 'cat__branch_Civil',
#        'cat__branch_ECE', 'cat__branch_IT', 'cat__branch_Mech',
#        'cat__hostel_No', 'cat__hostel_Yes'], dtype=object)

# %%
# 8 train and test split
from sklearn.model_selection import train_test_split

# %%
# 9 train the model 
from sklearn.
